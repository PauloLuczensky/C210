# %% [markdown]
# # Classificação de tipos de Íris
#
# <img src="https://github.com/alvaromfcunha-c210/aula2/blob/master/imagens/1.png?raw=1" alt= “1” height="600">
#
#
# <img src="https://github.com/alvaromfcunha-c210/aula2/blob/master/imagens/2.png?raw=1" alt= “2” height="300">

# %% [markdown]
# ### Carregar Dataset:

# %%
import pandas as pd
data = pd.read_csv("iris (1).csv")

#import io
#from google.colab import files

#uploaded = files.upload()
#file = io.BytesIO(uploaded['iris (1).csv'])
#data = pd.read_csv(file)

#Mostrando as 5 primeiras linhas
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ### Análise dos vetores de características:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
sns.scatterplot(
  data = data,
  x = "petal length (cm)",
  y = "petal width (cm)",
  hue = "target")
plt.title("Comprimento x Largura da Pétala")
plt.xlabel("Largura")
plt.ylabel("Comprimento")

plt.subplot(1,2,2)
sns.scatterplot(
  data = data,
  x = "sepal length (cm)",
  y = "sepal width (cm)",
  hue = "target")
plt.title("Comprimento x Largura da Sépala")
plt.xlabel("Largura")
plt.ylabel("Comprimento")

plt.show()

# %% [markdown]
# ### Preparação dos dados para Treinamento:

# %%
import numpy as np

#features -> características dos dados de entrada
fv = np.array(
    data.loc[:,["sepal length (cm)", "sepal width (cm)", "petal length (cm)", "petal width (cm)"]])

#target -> label de saída dos dados inseridos
labels = np.array(
    data['target'])

from sklearn.model_selection import train_test_split

#Separando as features de treino e teste, além das labels de treino e teste
fv_train, fv_test, labels_train, labels_test = train_test_split(fv, labels, test_size=0.2, random_state = 0)

# %% [markdown]
# ### Treinando modelos:

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Modelo usando algoritimo: K-Nearest Neighbours
knn = KNeighborsClassifier()
knn.fit(fv_train, labels_train)

# Modelo usando algoritimo: Decision Tree
tree = DecisionTreeClassifier()
tree.fit(fv_train, labels_train)

# Modelo usando algoritimo: Random Forest
rf = RandomForestClassifier()
rf.fit(fv_train, labels_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ### Testando e Avaliando modelos:

# %%
from sklearn.metrics import accuracy_score

knn_predict = knn.predict(fv_test)
knn_score = accuracy_score(labels_test, knn_predict)
print(f"Pontuação de precisão KNN: {knn_score}")

tree_predict = tree.predict(fv_test)
tree_score = accuracy_score(labels_test, tree_predict)
print(f"Pontuação de precisão Decision Tree: {tree_score}")

rf_predict = rf.predict(fv_test)
rf_score = accuracy_score(labels_test, rf_predict)
print(f"Pontuação de precisão Random Forest: {rf_score}")
# Out:
# Pontuação de precisão KNN: 0.9666666666666667
# Pontuação de precisão Decision Tree: 1.0
# Pontuação de precisão Random Forest: 0.9666666666666667
